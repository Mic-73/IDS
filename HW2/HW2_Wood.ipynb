# %% [markdown]
# Author Identification: Michael Wood

# %% [markdown]
# Problem 1: I downloaded the data and worked on it through Google Sheets.
#
# A. I addressed all missing values using the calculated average in the given columns. The only missing value was the assault rate in Georgia:
# ![Screenshot 2023-09-21 at 8.47.03 AM.png](data:image/png;base64,...)
#
# B. I looked for outliers using the means and standard deviations of the columns and found none. I also found no noisy data.
#
# C. I plotted the murder rates for all 50 states using a bar graph:
# ![Murder_Rate.png](data:image/png;base64,...)
#
# D. I plotted a histogram for the assaults:
# ![Assault Rates.png](data:image/png;base64,...)
#
# E. I plotted the Murder Rates vs Assault Rates using a scatter plot:
# ![MR vs AR.png](data:image/png;base64,...)
#
# F. I discretized the data in the UrbanPop column:
# ![UrbanPop.png](data:image/png;base64,...)

# %% [markdown]
# From the data, there does not seem to be a specific relationship between the murder and assault rates and the urban population percentage in each state.

# %% [markdown]
# Problem 1 (continued)
#
# Next, I converted this data into SQL. I found all the missing data of the columns using the column averages.
# ![Fixed missing value.png](data:image/png;base64,...)
#
# C. I then found the min, max, mean, and variance values:
#
# Min:
# Murder = 0.8,
# Assault = 45,
# UrbanPop = 32
#
# Max:
# Murder = 17.4,
# Assault = 337,
# UrbanPop = 91
#
# Mean:
# Murder = 7.787999999999999,
# Assault = 169.93877551020407,
# UrbanPop = 65.54
#
# Variance:
# Murder = 18.970465306122456,
# Assault = 6911.445231153684,
# UrbanPop = 209.51877551020405
#
# D. Use SQL to answer the following questions:
#
# -- Which state has the maximum murder rate?
#   Georgia
#
# -- List of states in ascending order of urban population percentages.
#
# State	UrbanPop
#
# Vermont	32
#
# West Virginia	39
#
# Mississippi	44
#
# North Dakota	44
#
# North Carolina	45
#
# South Dakota	45
#
# Alaska	48
#
# South Carolina	48
#
# Arkansas	50
#
# Maine	51
#
# Kentucky	52
#
# Montana	53
#
# Idaho	54
#
# New Hampshire	56
#
# Iowa	57
#
# Alabama	58
#
# Tennessee	59
#
# Georgia	60
#
# Wyoming	60
#
# Nebraska	62
#
# Virginia	63
#
# Indiana	65
#
# Kansas	66
#
# Louisiana	66
#
# Minnesota	66
#
# Wisconsin	66
#
# Maryland	67
#
# Oregon	67
#
# Oklahoma	68
#
# Missouri	70
#
# New Mexico	70
#
# Delaware	72
#
# Pennsylvania	72
#
# Washington	73
#
# Michigan	74
#
# Ohio	75
#
# Connecticut	77
#
# Colorado	78
#
# Arizona	80
#
# Florida	80
#
# Texas	80
#
# Utah	80
#
# Nevada	81
#
# Hawaii	83
#
# Illinois	83
#
# Massachusetts	85
#
# New York	86
#
# Rhode Island	87
#
# New Jersey	89
#
# California	91
#
# -- How many states have higher murder rates than Arizona? List those states.
# 21
#
# List:
# Alabama
#
# Alaska
#
# Arkansas
#
# California
#
# Florida
#
# Georgia
#
# Illinois
#
# Kentucky
#
# Louisiana
#
# Maryland
#
# Michigan
#
# Mississippi
#
# Missouri
#
# Nevada
#
# New Mexico
#
# New York
#
# North Carolina
#
# South Carolina
#
# Tennessee
#
# Texas
#
# Virginia

# %% [markdown]
# Analysis: From the data, it seems that there is a correlation between urban population percentage and murder and assault rates. However, it does not seem to be a strong correlation as states with a small urban population percentage can have high murder and assault rates, and large urban population percentages can also have low high murder and assault rates as well.

# %% [markdown]
# Problem 2:
#
# I organized the data into csv format.
#
# I filled in all the missing data values using the averages of the columns.
#
# Then, I prepared scatter plots for each of the required relations:
#
# --Under-ﬁve mortality rate and neonatal mortality rate.
# ![Screenshot 2023-09-21 at 11.05.43 AM.png](data:image/png;base64,...)
#
# --Infant mortality rate and neonatal mortality rate.
# ![Screenshot 2023-09-21 at 11.05.47 AM.png](data:image/png;base64,...)
#
# --Year and infant mortality rate.
# ![Screenshot 2023-09-21 at 11.05.52 AM.png](data:image/png;base64,...)
#
# Analysis: From these graphs, we can see that there is a positive correlation between Under-Fie Mortality Rate and Neonatal Mortality Rate. The same could be said for Infant Mortality Rate and Neonatal Mortality Rate. Infant Mortality Rate has also decreased throughout the years since 1990.

# %% [markdown]
# Problem 2 (continued):
#
# C. Answer the following queries in SQL:
#
# -- Which years have the lowest and highest infant mortality years, respectively?
#
# 1990 and 2016 respectively
#
# -- In what years the neonatal mortality rates were above average?
#
# 1990, 1991, 1992
# 1993,
# 1995,
# 1996,
# 1997,
# 1998,
# 1999,
# 2000,
# 2001,
# 2002,
# 2003
#
# -- Display the sorted infant mortality rates in descending order.
#
# I displayed the sorted infant mortality rates in descending order using this code:
#
# select Infant_mortality_rate
# from ChildMortality
# order by Infant_mortality_rate desc;
#
# -- Display min, max, mean, variance, and standard deviation for each mortality rate.
#
# Under-Five Mortality Rate:
# Min = 40.8,
# Max = 93.4,
# Mean = 68.67499999999998,
# Variance = 291.5040384615385
#
# Infant Mortality Rate
# Min = 30.5,
# Max = 64.8,
# Mean = 49.10833333307692,
# Variance = 118.8830128205129
#
# Neonatal Moratlity Rate:
# Min = 18.6,
# Max = 36.8,
# Mean = 27.644000000000005,
# Variance = 34.5308307692307
#
# -- Add a new column called Above-Five Mortality Rate and populate it with appropriate values. Hint: Use Alter Table Add Column.
#
# I added the new column and calculated the values by subtracting the Under-Five Mortality Rate values from 1000.
# Here is the new column:
# ![Screenshot 2023-09-21 at 11.46.50 AM.png](data:image/png;base64,...)

# %% [markdown]
# Analysis:
# Adding the new column AboveFive Mortality Rate helps confirm the earlier findings. It helps confirm that UnderFive Mortality Rate did decrease through the years since 1990 as aboveFive Mortality Rate increased. The UnderFive Mortality Rate is the highest and biggest mortality rate out of the starting three as seen in the min, max, mean, and variance values.
