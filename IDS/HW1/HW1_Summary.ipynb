# %% [markdown]
# Problem 1:
# I summarized the data of food types and chicken weights and concluded that Sunflower feed was the most beneficial for a thriving pultry business. The chickens that were given sunflower feed had the highest weights in the min, average, max, and sum values.
#
# Problem 2:
# I summarized the data of insurance provider ratings in a similar analysis of problem 1. I found that the auto insurance provider I would choose based off this analysis would be Progressive. While they did not have the highest rating in the entire data, they did have the most consistent ratings. Their average rating was the highest out of the three companies, and they had the highest sum of ratings as well.
#
# All data and analysis is available in the data files and worksheets within the IDS/HW1 repository.
